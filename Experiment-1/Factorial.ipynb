# %% [markdown]
# <a href="https://colab.research.google.com/github/physcoaryan/DataScienceLab/blob/main/Experiment-1/Factorial.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def factorial(n):
    if n < 0:
        return "Factorial is not defined for negative numbers."
    elif n == 0:
        return 1
    else:
        fact = 1
        for i in range(1, n + 1):
            fact *= i
        return fact

while True:
    user_input = input("Enter a non-negative integer to find its factorial: ")
    try:
        num = int(user_input)
        result = factorial(num)
        print(f"The factorial of {num} is: {result}")
        break # Exit the loop if input is valid
    except ValueError:
        print("Invalid input. Please enter an integer.")
# Out:
# Enter a non-negative integer to find its factorial: 6
# The factorial of 6 is: 720
