# %% [markdown]
# <a href="https://colab.research.google.com/github/physcoaryan/DataScienceLab/blob/main/Experiment-4/StatisticCalculations.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

def calculate_statistics(data):

    data_array = np.array(data)

    if data_array.size == 0:
        return {
            "mean": None,
            "median": None,
            "variance": None,
            "std_dev": None
        }

    mean = np.mean(data_array)
    median = np.median(data_array)
    # Using ddof=0 for population variance and standard deviation
    variance = np.var(data_array, ddof=0)
    std_dev = np.std(data_array, ddof=0)

    return {
        "mean": mean,
        "median": median,
        "variance": variance,
        "std_dev": std_dev
    }

# Example usage with a sample dataset
sample_data = [10, 12, 23, 23, 16, 23, 21, 16]
stats = calculate_statistics(sample_data)

print("--- Sample Data Statistics ---")
print(f"Data: {sample_data}")
print(f"Mean: {stats['mean']:.2f}")
print(f"Median: {stats['median']:.2f}")
print(f"Variance: {stats['variance']:.2f}")
print(f"Standard Deviation: {stats['std_dev']:.2f}")
# Out:
# --- Sample Data Statistics ---
# Data: [10, 12, 23, 23, 16, 23, 21, 16]
# Mean: 18.00
# Median: 18.50
# Variance: 24.00
# Standard Deviation: 4.90

# %% [markdown]
# Would you like to add functions to generate a random dataset or take input from the user?
